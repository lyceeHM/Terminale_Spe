# %%
import matplotlib.pyplot as plt
from random import *

plt.plot([random() for k in range(100)], [random() for k in range(100)], '.', color = 'red')
plt.show()
# Out:
# /lib/python3.8/site-packages/numpy/ma/core.py:4467: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.shape is ():

# %%
import pandas as pa

# %%
T = pa.DataFrame(data = {'X' : [1, 2], 'Y' : [0, 1] })
T
# Out:
#    X  Y
# 0  1  0
# 1  2  1

# %%
import requests
from io import StringIO

req = requests.get('http://maths.bro.free.fr/Files/the.csv',headers = {"User-Agent":"chrome"})
data = StringIO(req.text)
# Out:
# Error: Traceback (most recent call last):
#   File "/lib/python3.8/site-packages/requests/__init__.py", line 90, in onerror
#     raise ConnectionError(f"{error.js_error.toString()}{cors_message} Please check error message in browser console.")
# requests.ConnectionError: NetworkError: Failed to execute 'send' on 'XMLHttpRequest': Failed to load 'http://maths.bro.free.fr/Files/the.csv'. Requested URL is not on this domain. You may have CORS issue. Please check error message in browser console.

# %%
T = pd.read_csv('http://maths.bro.free.fr/Files/the.csv')
T
# Out:
# abort(abort(Assertion failed: undefined). Build with -s ASSERTIONS=1 for more info.). Build with -s ASSERTIONS=1 for more info.

# %%
import requests
from io import StringIO
# Out:
# abort(0). Build with -s ASSERTIONS=1 for more info.
