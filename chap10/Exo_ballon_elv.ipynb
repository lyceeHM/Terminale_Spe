# %% [markdown]
# <img src="https://raw.githubusercontent.com/lyceeHM/Terminale_Spe/master/python_lycee.png">
# <div id="titre">
# <h1 style="color:white;
#   font-family:Comic Sans MS;
#   font-size:3em;
#   background-color:black;
#   text-align:center;
#   padding:5px">Chute verticale d'un ballon</h1>
# <div style="font-family:Comic Sans MS; background-color:#888;box-shadow: 8px 8px 0px #aaa; text-align:center; width: 50%; color:white">TSPE : Primitives, équations différentielles</div>
# </div>

# %% [markdown]
# # <span style="font-size:1.3em;font-weight:bold;padding-right: 30px;"> 1.</span> Vitesse du ballon

# %% [markdown]
# <span style="font-size:2em;font-weight:bold;padding-right: 30px;"> b.</span>

# %%
from math import *
import matplotlib.pyplot as plt
plt.style.use('bmh')
plt.clf()

T = [0.0, 0.04, 0.08, 0.12, 0.16, 0.2, 0.24, 0.28, 0.32, 0.36, 0.4, 0.44, 0.48, 0.52, 0.56, 0.6, 0.64, 0.68, 0.72, 0.76, 0.8, 0.84]
V = [0.37, 0.55, 0.73, 0.93, 1.1, 1.29, 1.43, 1.63, 1.72, 1.9, 1.97, 2.11, 2.23, 2.25, 2.36, 2.36, 2.43, 2.37, 2.47, 2.54, 2.52, 2.63]

plt.plot(T, V, 'o-', color = 'black', markerfacecolor = 'white')
plt.show()

# %% [markdown]
# # <span style="font-size:1.3em;font-weight:bold;padding-right: 30px;"> 2.</span> Premier modèle : $f$ est proportionnelle à $v$

# %% [markdown]
# <span style="font-size:2em;font-weight:bold;padding-right: 30px;"> c.</span>  Fonction <code style="background-color:white;font-size:1.3em">v</code>

# %%
def v1(t):
    return ...

# %% [markdown]
# <span style="font-size:2em;font-weight:bold;padding-right: 30px;"> d.</span>  Reprsentation de la vitesse modélisée du ballon sur $\left[0\,;\,8,5\right]$

# %%
X = [k / 100 for k in range(86)]
Y = [... for t in X]
plt.plot(X, Y, color = 'red')

# %% [markdown]
# # <span style="font-size:1.3em;font-weight:bold;padding-right: 30px;"> 3.</span> Second modèle : $f$ est proportionnelle à $v^2$

# %% [markdown]
# <span style="font-size:2em;font-weight:bold;padding-right: 30px;"> b.</span>

# %%
x, y = 0, 0.37
X, Y = [x], [y]
h = 0.01
for k in range(86):
    y = y + ....
    x = x + ...
    X.append(x)
    Y.append(y)
    
plt.plot(X, Y, color = 'blue')
