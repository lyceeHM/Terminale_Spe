# %%
def distance(P1, P2):
    s = 0
    for k in range(3):
        s = s + (P1[k] - P2[k]) ** 2    
    return s ** 0.5

# %%
from random import *

def simulation(n):
    dmin = 10
    for i in range(n):
        k = uniform(-10, 10)
        M = [k, k, 2 * k]
        t = uniform(-10, 10)
        N = [..., ..., ...] 
        d = distance(M, ...)
        if d < dmin:
            kmin = ...
            tmin = ...
            dmin  = ...
            H1 = M
            H2 = ...
    return H1, H2, dmin, kmin, tmin

# %%
simulation(...)
# Out:
# ([0.26879724623320556, 0.26879724623320556, 0.5375944924664111], [0.3772743025240608, 0, 0.6227256974759392], 0.3021035474642067, 0.26879724623320556, -0.6227256974759392)
