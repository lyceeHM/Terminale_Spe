# %%
def distance(P1, P2):
    s = 0
    for k in range(3):
        s = s + (P1[k] - P2[k]) ** 2    
    return s ** 0.5

# %%
from random import *

def simulation(n):
    dmin = 10
    for i in range(n):
        k = uniform(-10, 10)
        A = [k, k, 2 * k]
        t = uniform(-10, 10)
        B = [..., ..., ...] 
        d = distance(M, ...)
        if d < dmin:
            kmin = ...
            tmin = ...
            dmin  = ...
            Amin = M
            Bmin = ...
    return Amin, Bmin, dmin, kmin, tmin

# %%
simulation(...)
